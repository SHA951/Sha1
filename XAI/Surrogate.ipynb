# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("diabetes.csv")

# %%
x = df.drop('Outcome',axis=1)
y = df['Outcome']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
model = RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(x_test,y_pred)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(dt_model,
          feature_names=x.columns,
          class_names=['Diabetes','No Diabetes'],
          filled=True,
         fontsize=3)
# Out:
# [Text(0.6666666666666666, 0.9375, 'Glucose <= 141.5\ngini = 0.403\nsamples = 154\nvalue = [111, 43]\nclass = Diabetes'),
#  Text(0.4444444444444444, 0.8125, 'SkinThickness <= 37.5\ngini = 0.228\nsamples = 122\nvalue = [106, 16]\nclass = Diabetes'),
#  Text(0.5555555555555556, 0.875, 'True  '),
#  Text(0.16666666666666666, 0.6875, 'Age <= 38.5\ngini = 0.154\nsamples = 107\nvalue = [98, 9]\nclass = Diabetes'),
#  Text(0.1111111111111111, 0.5625, 'gini = 0.0\nsamples = 79\nvalue = [79, 0]\nclass = Diabetes'),
#  Text(0.2222222222222222, 0.5625, 'Glucose <= 105.5\ngini = 0.436\nsamples = 28\nvalue = [19, 9]\nclass = Diabetes'),
#  Text(0.16666666666666666, 0.4375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Diabetes'),
#  Text(0.2777777777777778, 0.4375, 'BMI <= 31.15\ngini = 0.495\nsamples = 20\nvalue = [11, 9]\nclass = Diabetes'),
#  Text(0.1111111111111111, 0.3125, 'Pregnancies <= 8.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Diabetes'),
#  Text(0.05555555555555555, 0.1875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Diabetes'),
#  Text(0.16666666666666666, 0.1875, 'BMI <= 29.65\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = No Diabetes'),
#  Text(0.1111111111111111, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = No Diabetes'),
#  Text(0.2222222222222222, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Diabetes'),
#  Text(0.4444444444444444, 0.3125, 'Glucose <= 127.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = No Diabetes'),
#  Text(0.3888888888888889, 0.1875, 'DiabetesPedigreeFunction <= 0.342\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Diabetes'),
#  Text(0.3333333333333333, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Diabetes'),
#  Text(0.4444444444444444, 0.0625, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = No Diabetes'),
#  Text(0.5, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = No Diabetes'),
#  Text(0.7222222222222222, 0.6875, 'DiabetesPedigreeFunction <= 0.718\ngini = 0.498\nsamples = 15\nvalue = [8, 7]\nclass = Diabetes'),
#  Text(0.6666666666666666, 0.5625, 'Glucose <= 131.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = Diabetes'),
#  Text(0.6111111111111112, 0.4375, 'Age <= 42.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Diabetes'),
#  Text(0.5555555555555556, 0.3125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Diabetes'),
#  Text(0.6666666666666666, 0.3125, 'DiabetesPedigreeFunction <= 0.42\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Diabetes'),
#  Text(0.6111111111111112, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Diabetes'),
#  Text(0.7222222222222222, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Diabetes'),
#  Text(0.7222222222222222, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = No Diabetes'),
#  Text(0.7777777777777778, 0.5625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = No Diabetes'),
#  Text(0.8888888888888888, 0.8125, 'BMI <= 29.8\ngini = 0.264\nsamples = 32\nvalue = [5, 27]\nclass = No Diabetes'),
#  Text(0.7777777777777777, 0.875, '  False'),
#  Text(0.8333333333333334, 0.6875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Diabetes'),
#  Text(0.9444444444444444, 0.6875, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]\nclass = No Diabetes')]
