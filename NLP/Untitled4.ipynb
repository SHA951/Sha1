# %%
# !pip install keras
# !pip keras_preprocessing
# !pip install tensorFlow
# Out:
# ...
#   Using cached numpy-2.1.3-cp312-cp312-win32.whl.metadata (60 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/699.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/699.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/699.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/699.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/699.4 kB ? eta -:--:--
#      -------------- ------------------------- 262.1/699.4 kB ? eta -:--:--
#      -------------- ------------------------- 262.1/699.4 kB ? eta -:--:--
# ...

# %%
import sklearn
from sklearn.model_selection import train_train_split
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import sklearn
# ----> 2 from sklearn.model_selection import train_train_split
#       3 from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
#       4 from sklearn.preprocessing import LabelEncoder
#
# ImportError: cannot import name 'train_train_split' from 'sklearn.model_selection' (C:\Users\shakthi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\__init__.py)

# %%
import TensorFlow
from TensorFlow.keras import Sequential
from TensorFlow.keras.layers import Dense

# %%
data={"Text":["I am a good boy","I am a bad boy","NLP is amazing","NLP is tough"],
      "label":["positive","negative","positive","negative"]    
}
df=pd.DataFrame(data)
print(df)

# %%
label_encoder=LabelEncoder()
df['label']=label_encoder.fit_tansform(df['label'])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df['text'],df['label'],)

# %%
def build_model(input_dims):
    model=Sequential()
    model.add(Dense(16,activation="relu",input_dim=input_dims))
    model.add(Dense(8,activation="relu"))
    model.add(Dense(1,activation="sigmoid")
    model.compile(optimizer="adam",loss="binary_crossentropy",metrics=['accuracy'])
    return model
# Out:
#   Cell In[5], line 5
#     model.add(Dense(1,activation="sigmoid")
#              ^
# SyntaxError: '(' was never closed
