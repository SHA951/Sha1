# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"E:\daily-min-temperatures.csv")

# %%
df.head(5)
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
df.tail(5)
# Out:
#             Date  Temp
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0

# %%
df.shape
# Out:
# (3650, 2)

# %%
df.describe()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %%
df.info
# Out:
# <bound method DataFrame.info of             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]>

# %%
df["Date"]=pd.to_datetime(df["Date"])
df
# Out:
#            Date  Temp
# 0    1981-01-01  20.7
# 1    1981-01-02  17.9
# 2    1981-01-03  18.8
# 3    1981-01-04  14.6
# 4    1981-01-05  15.8
# ...         ...   ...
# 3645 1990-12-27  14.0
# 3646 1990-12-28  13.6
# 3647 1990-12-29  13.5
# 3648 1990-12-30  15.7
# 3649 1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df.groupby(by=["Date"])["Temp"].mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.set_index('Date',inplace=True)

# %%
df.loc['1981-01-01':'1982-12-21']
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1982-12-17  15.8
# 1982-12-18  13.0
# 1982-12-19  13.0
# 1982-12-20  13.7
# 1982-12-21  12.0
#
# [720 rows x 1 columns]

# %%
df.groupby(df.index.year).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
hist=df.hist(column='Temp')

# %%
df.value_counts()
# Out:
# Date        Temp
# 1981-01-01  20.7    1
# 1987-08-23  9.1     1
# 1987-08-25  10.6    1
# 1987-08-26  8.6     1
# 1987-08-27  10.1    1
#                    ..
# 1984-05-05  3.3     1
# 1984-05-06  3.5     1
# 1984-05-07  5.7     1
# 1984-05-08  5.5     1
# 1990-12-31  13.0    1
# Name: count, Length: 3650, dtype: int64
